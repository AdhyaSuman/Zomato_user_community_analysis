# %%
import pandas as pd
data = pd.read_csv('~path/reviews_data.csv')

# %%
data.head()
# Out:
#           Restaurant Name  Restaurant Id        User Name    User Id  \
# 0  Leaky Cauldron Kolkata     19089531.0   Susmita Mondal  118650082
# 1  Leaky Cauldron Kolkata     19089531.0  Sayon Mukherjee   29293643
# 2  Leaky Cauldron Kolkata     19089531.0    Soham Bhaduri     657702
# 3  Leaky Cauldron Kolkata     19089531.0      Teena Panda   76785732
# 4  Leaky Cauldron Kolkata     19089531.0    Upasana Ghosh   46441933
#
#                                            User Link  User Rating  \
# 0  https://www.zomato.com/users/susmita-mondal-11...          5.0
# 1  https://www.zomato.com/users/sayon-mukherjee-2...          4.0
# 2  https://www.zomato.com/users/soham-bhaduri-657702          5.0
# 3  https://www.zomato.com/users/teena-panda-76785732          4.0
# 4  https://www.zomato.com/users/upasana-ghosh-464...          5.0
#
#            Review Time                                        Review Text
# 0  2019-07-06 17:46:05  It's a very nice place with decor.. The people...
# 1  2019-07-06 11:36:58  Really wanted to try this place and see how th...
# 2  2019-07-05 12:14:48  This place is an absolute must visit if for a ...
# 3  2019-06-30 07:42:53  The lamb was outstanding but the fire whiskey ...
# 4  2019-06-25 21:33:27  Honestly speaking, I hadn't expected the place...

# %%
data['User Rating'].value_counts()
# Out:
# 5.0    166787
# 4.0    154265
# 3.0     64485
# 1.0     59411
# 4.5     57347
# 3.5     47949
# 2.0     25105
# 2.5     10155
# 1.5      4513
# Name: User Rating, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Get the distribution of the ratings
x=data['User Rating'].value_counts()
x=x.sort_index()
#plot
plt.figure(figsize=(8,4), dpi = 500)
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("User Rating Distribution")
plt.ylabel('# of ratings', fontsize=12)
plt.xlabel('Star Ratings ', fontsize=12)

#adding the text labels
rects = ax.patches
labels = x.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

#plt.show()
plt.savefig('~path/rating_dist.jpg')
